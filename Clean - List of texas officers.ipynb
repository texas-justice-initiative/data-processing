# %% [markdown]
# # Clean data about individual police officers
#
# * Input: `raw_list_of_texas_officers.csv`
# * Output: `list_of_texas_officers.csv`
#
# ##### Author: Everett Wetchler (everett.wetchler@gmail.com)

# %% [markdown]
# ## 1. Setup and read data

# %%
DTW_PROJECT_KEY = 'tji/auxiliary-datasets'
RAW_DATAFRAME_NAME = 'raw_list_of_texas_officers'
AGENCY_COUNTY_DATAFRAME = 'agencies_and_counties'
CLEANED_FILENAME = 'list_of_texas_officers.csv'

# %%
import datadotworld as dw
import numpy as np
import pandas as pd

# %load_ext watermark
# %watermark -a "Everett Wetchler" -d -t -z -r -g -w -p datadotworld,numpy,pandas
# Out:
# Everett Wetchler 2018-05-08 17:13:41 CDT
#
# datadotworld 1.6.0
# numpy 1.14.3
# pandas 0.22.0
# Git hash: 1dac51453f53e9273617aeef9ca4267dee5a09cb
# Git repo: git@github.com:texas-justice-initiative/data-processing.git
# watermark 1.6.0

# %%
from lib.standardize_police_agency_names import standardize_agency_name

# %%
datasets = dw.load_dataset(DTW_PROJECT_KEY, force_update=True)
agency_county = datasets.dataframes[AGENCY_COUNTY_DATAFRAME]
agency_county.head()
# Out:
#                          agency    county
# 0       ANDERSON CO CONST PCT 1  ANDERSON
# 1       ANDERSON CO CONST PCT 2  ANDERSON
# 2       ANDERSON CO CONST PCT 3  ANDERSON
# 3       ANDERSON CO CONST PCT 4  ANDERSON
# 4  ANDERSON CO DIST ATTY OFFICE  ANDERSON

# %%
df = datasets.dataframes[RAW_DATAFRAME_NAME]
df.head()
# Out:
#   first_name middle     last_name suffix               current_department  \
# 0   BRADFORD      E        TIPPIT    NaN       MISSOURI CITY POLICE DEPT.
# 1      ROGER      W       KENDALL    NaN  TEXAS BOARD OF CRIMINAL JUSTICE
# 2    CHARLES      T        KELLEY    NaN  WILLIAMSON CO. SHERIFF'S OFFICE
# 3       NAYA      C          POPE    NaN              IRVING POLICE DEPT.
# 4      LINDA      F  HARTT-GOGGIN    NaN             ANTHONY POLICE DEPT.
#
#            highest_cert  service_time
# 0  Master Peace Officer         23.92
# 1  Master Peace Officer         25.67
# 2  Master Peace Officer         23.41
# 3  Master Peace Officer         36.91
# 4  Master Peace Officer         32.41

# %% [markdown]
# ## 2. Begin cleaning

# %% [markdown]
# ### Standardize agency names

# %%
df['current_department'] = df['current_department'].apply(standardize_agency_name)
df.head()
# Out:
#   first_name middle     last_name suffix               current_department  \
# 0   BRADFORD      E        TIPPIT    NaN        MISSOURI CITY POLICE DEPT
# 1      ROGER      W       KENDALL    NaN  TEXAS BOARD OF CRIMINAL JUSTICE
# 2    CHARLES      T        KELLEY    NaN    WILLIAMSON CO SHERIFFS OFFICE
# 3       NAYA      C          POPE    NaN               IRVING POLICE DEPT
# 4      LINDA      F  HARTT-GOGGIN    NaN              ANTHONY POLICE DEPT
#
#            highest_cert  service_time
# 0  Master Peace Officer         23.92
# 1  Master Peace Officer         25.67
# 2  Master Peace Officer         23.41
# 3  Master Peace Officer         36.91
# 4  Master Peace Officer         32.41

# %% [markdown]
# ### Add county names

# %%
agency_to_county = dict(zip(agency_county.agency, agency_county.county))
df['current_department_county'] = df['current_department'].apply(lambda d: agency_to_county.get(d, None))
df['current_department_county'].isnull().value_counts()
# Out:
# False    77759
# True        41
# Name: current_department_county, dtype: int64

# %%
df['current_department'][df['current_department_county'].isnull()].value_counts()
# Out:
# ALABAMA-COUSHATTA TRIBE OF TEXAS POLICE DEPT    17
# STAFFORD FIRE MARSHALS OFFICE                    6
# HIDALGO CO CONST PCT 5                           5
# TENAHA POLICE DEPT                               4
# RICHLAND POLICE DEPT                             2
# UNIV OF DALLAS POLICE DEPT                       2
# DUMAS FIRE DEPT                                  1
# FRANKLIN CO FIRE MARSHALS OFFICE                 1
# COKE CO CONST PCT                                1
# HAMILTON CO CONST PCT 3                          1
# 50TH JUDICIAL DIST ATTY OFFICE                   1
# Name: current_department, dtype: int64

# %% [markdown]
# ### Uppercase string values

# %%
for c in df.columns:
    df[c] = df[c].apply(lambda val: val if not isinstance(val, str) else val.upper())
df.head()
# Out:
#   first_name middle     last_name suffix               current_department  \
# 0   BRADFORD      E        TIPPIT    NaN        MISSOURI CITY POLICE DEPT
# 1      ROGER      W       KENDALL    NaN  TEXAS BOARD OF CRIMINAL JUSTICE
# 2    CHARLES      T        KELLEY    NaN    WILLIAMSON CO SHERIFFS OFFICE
# 3       NAYA      C          POPE    NaN               IRVING POLICE DEPT
# 4      LINDA      F  HARTT-GOGGIN    NaN              ANTHONY POLICE DEPT
#
#            highest_cert  service_time current_department_county
# 0  MASTER PEACE OFFICER         23.92                 FORT BEND
# 1  MASTER PEACE OFFICER         25.67                    WALKER
# 2  MASTER PEACE OFFICER         23.41                WILLIAMSON
# 3  MASTER PEACE OFFICER         36.91                    DALLAS
# 4  MASTER PEACE OFFICER         32.41                   EL PASO

# %% [markdown]
# ### Add 'full_name' column

# %%
df['full_name'] = ''
for col in ['first_name', 'middle', 'last_name', 'suffix']:
    df['full_name'] = df['full_name'] + ' ' + df[col].fillna('')
df['full_name'] = df['full_name'].apply(lambda s: ' '.join(s.strip().split()))
df.sample(5)
# Out:
#       first_name middle   last_name suffix                current_department  \
# 24410    MICHAEL    NaN  DE LA ROSA    NaN          PFLUGERVILLE POLICE DEPT
# 62116    KENDALL      A       CASEY    NaN             HENDERSON POLICE DEPT
# 30455     RAFAEL    NaN      MONTES    NaN           HOUSTON ISD POLICE DEPT
# 60315       ANNA      M   RODRIGUEZ    NaN  BLINN JUNIOR COLLEGE POLICE DEPT
# 39052      CRAIG      S    HOLLEMAN    NaN            LEWISVILLE POLICE DEPT
#
#                      highest_cert  service_time current_department_county  \
# 24410        MASTER PEACE OFFICER         21.75                    TRAVIS
# 62116                         NaN          0.17                      RUSK
# 30455         BASIC PEACE OFFICER          2.58                    HARRIS
# 60315  INTERMEDIATE PEACE OFFICER          5.91                WASHINGTON
# 39052      ADVANCED PEACE OFFICER         14.92                    DENTON
#
#                 full_name
# 24410  MICHAEL DE LA ROSA
# 62116     KENDALL A CASEY
# 30455       RAFAEL MONTES
# 60315    ANNA M RODRIGUEZ
# 39052    CRAIG S HOLLEMAN

# %% [markdown]
# ### Reorder and rename columns, sort values

# %%
df = df[['first_name', 'middle', 'last_name', 'suffix', 'full_name',
         'current_department', 'current_department_county',
         'highest_cert', 'service_time']]

df.columns = ['name_first', 'name_middle', 'name_last', 'name_suffix', 'name_full',
              'current_agency', 'current_agency_county',
              'highest_cert', 'service_time']

df.sort_values(['current_agency_county', 'current_agency', 'name_full'], inplace=True)
df.head(10)
# Out:
#       name_first name_middle  name_last name_suffix            name_full  \
# 1170        DALE           E   SCHNELLE         NaN      DALE E SCHNELLE
# 13899       GARY           D     THOMAS         NaN        GARY D THOMAS
# 7477     CHARLES           D  LIGHTFOOT         NaN  CHARLES D LIGHTFOOT
# 13900    WILLIAM           R      WATTS         NaN      WILLIAM R WATTS
# 32218   KIMBERLY           S   HOLLIDAY         NaN  KIMBERLY S HOLLIDAY
# 16327      JAMES           O      MUNIZ         NaN        JAMES O MUNIZ
# 36024    ANESHIA           D   THOMPSON         NaN   ANESHIA D THOMPSON
# 51088      CATHY           J     STONER         NaN       CATHY J STONER
# 32743       RYAN           N   TOLLIVER         NaN      RYAN N TOLLIVER
# 56178     ANDREA           N   KARRIKER         NaN    ANDREA N KARRIKER
#
#                      current_agency current_agency_county  \
# 1170        ANDERSON CO CONST PCT 1              ANDERSON
# 13899       ANDERSON CO CONST PCT 1              ANDERSON
# 7477        ANDERSON CO CONST PCT 2              ANDERSON
# 13900       ANDERSON CO CONST PCT 2              ANDERSON
# 32218       ANDERSON CO CONST PCT 3              ANDERSON
# 16327       ANDERSON CO CONST PCT 4              ANDERSON
# 36024  ANDERSON CO DIST ATTY OFFICE              ANDERSON
# 51088  ANDERSON CO DIST ATTY OFFICE              ANDERSON
# 32743  ANDERSON CO DIST ATTY OFFICE              ANDERSON
# 56178   ANDERSON CO SHERIFFS OFFICE              ANDERSON
#
#                      highest_cert  service_time
# 1170         MASTER PEACE OFFICER         22.92
# 13899        MASTER PEACE OFFICER         43.00
# 7477         MASTER PEACE OFFICER         24.67
# 13900        MASTER PEACE OFFICER         23.25
# 32218        MASTER PEACE OFFICER         17.33
# 16327        MASTER PEACE OFFICER         25.82
# 36024      ADVANCED PEACE OFFICER         16.25
# 51088        MASTER PEACE OFFICER          9.75
# 32743      ADVANCED PEACE OFFICER         14.75
# 56178  INTERMEDIATE PEACE OFFICER          5.58

# %% [markdown]
# ## 3. Write

# %%
with dw.open_remote_file(DTW_PROJECT_KEY, CLEANED_FILENAME) as w:
    print("Writing to data.world:", CLEANED_FILENAME)
    df.to_csv(w, index=False)
# Out:
# Writing to data.world: list_of_texas_officers.csv
