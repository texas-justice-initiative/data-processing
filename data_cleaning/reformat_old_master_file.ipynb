# %% [markdown]
# # Reformat old CDR master file for incorporation in new CDR dataset
#
# ### About the data
#
# "Prior to 2013, the OIG only completed forms for unattended deaths (deaths that did not occur in an inpatient setting).  Beginning in January 2013, they began completing the form for all deaths."
#
# [Here's](http://gritsforbreakfast.blogspot.com/2014/12/tdcj-reporting-change-explains-death-in.html) a blog post about this change.
#
# Our CDR data, obtained via email from the Texas AG, does not include these deaths. In the previous version of the TJI website (2017), this missing data was obtained from the Texas Bureau of Justice Statistics (BJS), merged with the CDR data, and placed in a "master file," used by the old website.
#
# This notebook reformats this old master file to be incorporated into our existing CDR data cleaning pipeline.
#
# See the `clean_cdr.ipynb` file for how the output of this notebook is incorporated.
#
# ### Datasets used
#
# Input:
# * `tji/raw-and-processingcdr_2017_master_file.csv`
#
# Output:
# * `tji/raw-and-processing/reformatted_cdr_2017_master_file.csv`
#
# ##### Author: Everett Wetchler (everett.wetchler@gmail.com)

# %%
DTW_PROJECT_KEY = 'tji/raw-and-processing'
RAW_FILENAME = 'original/cdr_2017_master_file.csv'
CLEANED_FILENAME = 'reformatted_cdr_2017_master_file.csv'

# %%
import datadotworld as dw
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %load_ext watermark
# %watermark -a 'Everett Wetchler' -d -t -z -w -p numpy,pandas,matplotlib,datadotworld
# Out:
# Everett Wetchler 2018-05-28 23:15:53 CDT
#
# numpy 1.14.3
# pandas 0.22.0
# matplotlib 2.2.0
# datadotworld 1.6.0
# watermark 1.6.0

# %%
from lib.cleaning_tools import *

# %%
df = read_dtw_csv(DTW_PROJECT_KEY, RAW_FILENAME, encoding='latin-1')
print(df.shape)
df.head()
# Out:
# Writing CSV to temp file: /var/folders/dc/8cbxbsh515s908xl0zyprszm0000gn/T/tmp2oqj9cve
# (7735, 94)
#      report_date       pa_number department_type  \
# 0  3/1/2005 0:00  PRISON20051001        STAGENCY
# 1  3/1/2005 0:00  PRISON20051002        STAGENCY
# 2  3/1/2005 0:00  PRISON20051004        STAGENCY
# 3  3/1/2005 0:00  PRISON20051005        STAGENCY
# 4  3/1/2005 0:00  PRISON20051007        STAGENCY
#
#                         department_name department_address department_city  \
# 0  Texas Department Of Criminal Justice                NaN             NaN
# 1  Texas Department Of Criminal Justice                NaN             NaN
# 2  Texas Department Of Criminal Justice                NaN             NaN
# 3  Texas Department Of Criminal Justice                NaN             NaN
# 4  Texas Department Of Criminal Justice                NaN             NaN
#
#   department_state  department_zip department_phone department_county  \
# 0               TX             NaN              NaN               NaN
# 1               TX             NaN              NaN               NaN
# 2               TX             NaN              NaN               NaN
# 3               TX             NaN              NaN               NaN
# 4               TX             NaN              NaN               NaN
#
#   director_envelope director_salutation director_first_name  \
# 0               NaN                 NaN                 NaN
# 1               NaN                 NaN                 NaN
# 2               NaN                 NaN                 NaN
# 3               NaN                 NaN                 NaN
# 4               NaN                 NaN                 NaN
#
#   director_middle_name director_last_name reporter_name reporter_email  \
# 0                  NaN                NaN           NaN            NaN
# 1                  NaN                NaN           NaN            NaN
# 2                  NaN                NaN           NaN            NaN
# 3                  NaN                NaN           NaN            NaN
# 4                  NaN                NaN           NaN            NaN
#
#   first_name middle_name last_name suffix                  ethnicity  \
# 0      Clyde           L      Pady    NaN             Anglo or White
# 1    Winston         NaN   Wilkins    NaN             Anglo or White
# 2     Steven         NaN   Fleming    NaN  Black or African American
# 3      James           B    Walker    NaN  Black or African American
# 4      David           L     Jones    NaN             Anglo or White
#
#   ethnicity_other   sex  birth_date   age    custody_date  custody_date_na  \
# 0             NaN  Male   10/1/2024  80.0  5/30/1995 0:00              NaN
# 1             NaN  Male   9/27/1943  61.0   9/8/2003 0:00              NaN
# 2             NaN  Male  10/30/1967  37.0  10/7/1988 0:00              NaN
# 3             NaN  Male   8/27/1943  61.0  4/23/2004 0:00              NaN
# 4             NaN  Male    5/1/1960  45.0  11/8/2001 0:00              NaN
#
#   death_date death_address       death_city death_county medical_evaluation  \
# 0   1/2/2005           NaN  Tenessee Colony          NaN                 No
# 1   1/2/2005           NaN        Galveston          NaN                 No
# 2   1/4/2005           NaN       Livingston          NaN                 No
# 3   1/4/2005           NaN  Tenessee Colony          NaN                 No
# 4   1/6/2005           NaN          Abilene          NaN                 No
#
#              manner_death      manner_death_description medical_cause_death  \
# 0  Natural Causes/Illness          Prostate/Lung Cancer                 NaN
# 1  Natural Causes/Illness                   Lung Cancer                 NaN
# 2  Natural Causes/Illness                           NaN                 NaN
# 3  Natural Causes/Illness         Hepatocellular Cancer                 NaN
# 4  Natural Causes/Illness  Cardiomyopathy Heart Failure                 NaN
#
#                      medical_condition medical_treatment  \
# 0  Developed condition after admission               Yes
# 1       Pre-existing medical condition               Yes
# 2       Pre-existing medical condition               Yes
# 3  Developed condition after admission               Yes
# 4       Pre-existing medical condition               Yes
#
#   medical_treatment_description custody_general custody_type  \
# 0                           NaN    Penitentiary         TDCJ
# 1                           NaN    Penitentiary         TDCJ
# 2                           NaN    Penitentiary         TDCJ
# 3                           NaN    Penitentiary         TDCJ
# 4                           NaN    Penitentiary         TDCJ
#
#   custody_type_facility                                     charges_1  \
# 0               Michael           SEXUAL ASSLT/RAPE OF CHILD 11190000
# 1    Hospital Galveston     STOLEN VEHICLE, UNAUTHORIZED USE 24110000
# 2              Polunsky      SEXUAL ASSLT/RAPE AGG/SEX ABUSE 11180000
# 3               Michael                     AGG SEXUAL ASSLT 11990003
# 4             Robertson  INDECENCY W/ A CHILD SEXUAL CONTACT 36010001
#
#                              charges_2                            charges_3  \
# 0  SEXUAL ASSLT/RAPE OF CHILD 11190000  SEXUAL ASSLT/RAPE OF CHILD 11190000
# 1                                    0                                    0
# 2                                    0                                    0
# 3              AGG KIDNAPPING 10990004                                    0
# 4                                    0                                    0
#
#   charges_status  charges_violent  charges_child  charges_property  \
# 0      Convicted              0.0            1.0               0.0
# 1      Convicted              0.0            0.0               1.0
# 2      Convicted              1.0            0.0               0.0
# 3      Convicted              1.0            0.0               0.0
# 4      Convicted              0.0            1.0               0.0
#
#    charges_drug  charges_other charges_other_description death_reason  \
# 0           0.0            0.0                       NaN          NaN
# 1           0.0            0.0                       NaN          NaN
# 2           0.0            0.0                       NaN          NaN
# 3           0.0            0.0                       NaN          NaN
# 4           0.0            0.0                       NaN          NaN
#
#    injured_by_officers  injured_by_others  injured_by_self_accident  \
# 0                  NaN                NaN                       NaN
# 1                  NaN                NaN                       NaN
# 2                  NaN                NaN                       NaN
# 3                  NaN                NaN                       NaN
# 4                  NaN                NaN                       NaN
#
#    injured_by_suicide  injured_by_unknown  injured_by_na under_restraint  \
# 0                 NaN                 NaN            NaN             NaN
# 1                 NaN                 NaN            NaN             NaN
# 2                 NaN                 NaN            NaN             NaN
# 3                 NaN                 NaN            NaN             NaN
# 4                 NaN                 NaN            NaN             NaN
#
#    restraint_handcuffs  restraint_shackles  restraint_other  \
# 0                  NaN                 NaN              NaN
# 1                  NaN                 NaN              NaN
# 2                  NaN                 NaN              NaN
# 3                  NaN                 NaN              NaN
# 4                  NaN                 NaN              NaN
#
#   restraint_other_description  appear_intoxicated  threaten_officers  \
# 0                         NaN                 NaN                NaN
# 1                         NaN                 NaN                NaN
# 2                         NaN                 NaN                NaN
# 3                         NaN                 NaN                NaN
# 4                         NaN                 NaN                NaN
#
#    resist_arrest  attempt_escape  fight_officers  use_weapon_officers  \
# 0            NaN             NaN             NaN                  NaN
# 1            NaN             NaN             NaN                  NaN
# 2            NaN             NaN             NaN                  NaN
# 3            NaN             NaN             NaN                  NaN
# 4            NaN             NaN             NaN                  NaN
#
#   use_weapon_officers_description  behavior_other behavior_other_description  \
# 0                             NaN             NaN                        NaN
# 1                             NaN             NaN                        NaN
# 2                             NaN             NaN                        NaN
# 3                             NaN             NaN                        NaN
# 4                             NaN             NaN                        NaN
#
#    behavior_na  death_weapon_handgun  death_weapon_rifle  death_weapon_baton  \
# 0          NaN                   NaN                 NaN                 NaN
# 1          NaN                   NaN                 NaN                 NaN
# 2          NaN                   NaN                 NaN                 NaN
# 3          NaN                   NaN                 NaN                 NaN
# 4          NaN                   NaN                 NaN                 NaN
#
#    death_weapon_tazer  death_weapon_other death_weapon_other_description  \
# 0                 NaN                 NaN                            NaN
# 1                 NaN                 NaN                            NaN
# 2                 NaN                 NaN                            NaN
# 3                 NaN                 NaN                            NaN
# 4                 NaN                 NaN                            NaN
#
#    death_weapon_na death_location death_location_elsewhere entry_date  \
# 0              NaN            NaN                      NaN        NaN
# 1              NaN            NaN                      NaN        NaN
# 2              NaN            NaN                      NaN        NaN
# 3              NaN            NaN                      NaN        NaN
# 4              NaN            NaN                      NaN        NaN
#
#    entry_date_na  entry_behavior_intoxicated  entry_behavior_mental  \
# 0            NaN                         NaN                    NaN
# 1            NaN                         NaN                    NaN
# 2            NaN                         NaN                    NaN
# 3            NaN                         NaN                    NaN
# 4            NaN                         NaN                    NaN
#
#    entry_behavior_medical  entry_behavior_na death_causer death_causer_other  \
# 0                     NaN                NaN          NaN                NaN
# 1                     NaN                NaN          NaN                NaN
# 2                     NaN                NaN          NaN                NaN
# 3                     NaN                NaN          NaN                NaN
# 4                     NaN                NaN          NaN                NaN
#
#   death_means death_means_other Summary
# 0         NaN               NaN     NaN
# 1         NaN               NaN     NaN
# 2         NaN               NaN     NaN
# 3         NaN               NaN     NaN
# 4         NaN               NaN     NaN

# %% [markdown]
# ## Collapse binary "entry behavior" columns into a single string column

# %%
df['entry_behavior'] = ''
for suffix in ('intoxicated', 'medical', 'mental'):
    c = 'entry_behavior_%s' % suffix
    s = df[c].apply(lambda x: suffix if x == 1.0 else '')
    df['entry_behavior'] = df['entry_behavior'] + ' ' + s

df['entry_behavior'] = df['entry_behavior'].apply(lambda x: ('; '.join(x.strip().split())) if x.strip() else None)
df['entry_behavior'].value_counts()
# Out:
# medical                         322
# intoxicated                     192
# mental                           84
# medical; mental                  40
# intoxicated; medical             29
# intoxicated; mental              19
# intoxicated; medical; mental     13
# Name: entry_behavior, dtype: int64

# %%
df['charges'] = ''
for suffix in ('violent', 'child', 'property', 'drug', 'other'):
    c = 'charges_%s' % suffix
    s = df[c].apply(lambda x: suffix if x == 1.0 else '')
    df['charges'] = df['charges'] + ' ' + s

df['charges'] = df['charges'].apply(lambda x: ('; '.join(x.strip().split())) if x.strip() else None)
df['charges'].value_counts()
# Out:
# violent                           2808
# drug                              1244
# other                              890
# property                           817
# child                              693
# violent; child                     107
# violent; property                  101
# violent; drug                       76
# drug; other                         55
# violent; other                      27
# property; drug                      26
# violent; property; drug             13
# property; other                     12
# violent; drug; other                 7
# child; other                         5
# child; drug                          5
# violent; property; other             4
# property; drug; other                3
# child; property                      2
# violent; child; property             2
# violent; child; drug                 1
# violent; child; other                1
# child; property; drug                1
# violent; property; drug; other       1
# Name: charges, dtype: int64

# %% [markdown]
# ## Remove numerical charge code where present

# %%
df.charges_1.value_counts().head()
# Out:
# Murder                                            296
# Aggravated Sexual Assault of a Child              166
# HOMICIDE-MURDER 09150000                          153
# DRIVING WHILE INTOXICATED 3RD OR MORE 54040011    145
# SEXUAL ASSLT/RAPE AGG/SEX ABUSE 11180000          138
# Name: charges_1, dtype: int64

# %%
def remove_code(charge):
    if pd.isnull(charge):
        return None
    parts = charge.split()
    if parts[-1].isdigit() and len(parts[-1]) > 5:
        return ' '.join(parts[:-1])
    else:
        return charge

for i in range(1, 4):
    col = 'charges_%d' % i
    df[col] = df[col].apply(remove_code)

df.charges_1.value_counts().head()
# Out:
# Murder                                   296
# Aggravated Sexual Assault of a Child     166
# HOMICIDE-MURDER                          153
# DRIVING WHILE INTOXICATED 3RD OR MORE    145
# SEXUAL ASSLT/RAPE AGG/SEX ABUSE          138
# Name: charges_1, dtype: int64

# %% [markdown]
# ## Rename columns to align with the other CDR dataset

# %%
col_renames = {
    'first_name': None,
    'middle_name': None,
    'last_name': None,
    'suffix': None,
    'age': 'age_at_time_of_death',
    'sex': 'sex',
    'birth_date': 'date_of_birth',
    'charges_1': 'offense_1',
    'charges_2': 'offense_2',
    'charges_3': 'offense_3',
    'report_date': None,
    'death_date': 'death_date_and_time',
    'pa_number': 'cdr_cdr_name',
    'department_name': 'agency_name',
    'department_address': 'agency_address',
    'department_city': 'agency_city',
    'department_zip': 'agency_zip',
    'department_county': 'agency_county',
    'death_causer': 'who_caused_the_death',
    'death_causer_other': None,
    'custody_date': 'date_time_of_custody_or_incident',
    'custody_date_na': None,
    'custody_general': 'type_of_custody',
    'custody_type': 'specific_type_of_custody_facility',
    'death_address': 'street_address',
    'death_city': 'city',
    'death_county': 'county',
    'death_location': None,
    'death_location_elsewhere': None,
    'death_means': 'means_of_death',
    'death_means_other': 'means_of_death_other',
    'manner_death': 'manner_of_death',
    'manner_death_description': 'manner_of_death_description',
    'entry_date': 'entry_date_time',
    'entry_date_na': 'entry_date_time_n_a',
    'medical_cause_death': 'medical_cause_of_death',
    'medical_condition': 'pre_existing_medical_condition',
    'medical_evaluation': 'medical_examinor_coroner_evalution',
    'medical_treatment': None,
    'ethnicity': None,
    'ethnicity_other': None,
    'behavior_other_description': 'other_behavior',
    'entry_behavior': None,
    'charges_status': 'were_the_charges',
    'charges': 'type_of_offense',
    'charges_other_description': 'type_of_offense_other',
}

# %%
# Drop unnecessary columns
df = df[list(col_renames.keys())]
# Rename (if the rename value is 'None', keep the original name)
df.columns = [col_renames[c] or c for c in df.columns]

# %%
df.head()
# Out:
#   first_name middle_name last_name suffix  age_at_time_of_death   sex  \
# 0      Clyde           L      Pady    NaN                  80.0  Male
# 1    Winston         NaN   Wilkins    NaN                  61.0  Male
# 2     Steven         NaN   Fleming    NaN                  37.0  Male
# 3      James           B    Walker    NaN                  61.0  Male
# 4      David           L     Jones    NaN                  45.0  Male
#
#   date_of_birth                            offense_1  \
# 0     10/1/2024           SEXUAL ASSLT/RAPE OF CHILD
# 1     9/27/1943     STOLEN VEHICLE, UNAUTHORIZED USE
# 2    10/30/1967      SEXUAL ASSLT/RAPE AGG/SEX ABUSE
# 3     8/27/1943                     AGG SEXUAL ASSLT
# 4      5/1/1960  INDECENCY W/ A CHILD SEXUAL CONTACT
#
#                     offense_2                   offense_3    report_date  \
# 0  SEXUAL ASSLT/RAPE OF CHILD  SEXUAL ASSLT/RAPE OF CHILD  3/1/2005 0:00
# 1                           0                           0  3/1/2005 0:00
# 2                           0                           0  3/1/2005 0:00
# 3              AGG KIDNAPPING                           0  3/1/2005 0:00
# 4                           0                           0  3/1/2005 0:00
#
#   death_date_and_time    cdr_cdr_name                           agency_name  \
# 0            1/2/2005  PRISON20051001  Texas Department Of Criminal Justice
# 1            1/2/2005  PRISON20051002  Texas Department Of Criminal Justice
# 2            1/4/2005  PRISON20051004  Texas Department Of Criminal Justice
# 3            1/4/2005  PRISON20051005  Texas Department Of Criminal Justice
# 4            1/6/2005  PRISON20051007  Texas Department Of Criminal Justice
#
#   agency_address agency_city  agency_zip agency_county who_caused_the_death  \
# 0            NaN         NaN         NaN           NaN                  NaN
# 1            NaN         NaN         NaN           NaN                  NaN
# 2            NaN         NaN         NaN           NaN                  NaN
# 3            NaN         NaN         NaN           NaN                  NaN
# 4            NaN         NaN         NaN           NaN                  NaN
#
#   death_causer_other date_time_of_custody_or_incident  custody_date_na  \
# 0                NaN                   5/30/1995 0:00              NaN
# 1                NaN                    9/8/2003 0:00              NaN
# 2                NaN                   10/7/1988 0:00              NaN
# 3                NaN                   4/23/2004 0:00              NaN
# 4                NaN                   11/8/2001 0:00              NaN
#
#   type_of_custody specific_type_of_custody_facility street_address  \
# 0    Penitentiary                              TDCJ            NaN
# 1    Penitentiary                              TDCJ            NaN
# 2    Penitentiary                              TDCJ            NaN
# 3    Penitentiary                              TDCJ            NaN
# 4    Penitentiary                              TDCJ            NaN
#
#               city county death_location death_location_elsewhere  \
# 0  Tenessee Colony    NaN            NaN                      NaN
# 1        Galveston    NaN            NaN                      NaN
# 2       Livingston    NaN            NaN                      NaN
# 3  Tenessee Colony    NaN            NaN                      NaN
# 4          Abilene    NaN            NaN                      NaN
#
#   means_of_death means_of_death_other         manner_of_death  \
# 0            NaN                  NaN  Natural Causes/Illness
# 1            NaN                  NaN  Natural Causes/Illness
# 2            NaN                  NaN  Natural Causes/Illness
# 3            NaN                  NaN  Natural Causes/Illness
# 4            NaN                  NaN  Natural Causes/Illness
#
#     manner_of_death_description entry_date_time  entry_date_time_n_a  \
# 0          Prostate/Lung Cancer             NaN                  NaN
# 1                   Lung Cancer             NaN                  NaN
# 2                           NaN             NaN                  NaN
# 3         Hepatocellular Cancer             NaN                  NaN
# 4  Cardiomyopathy Heart Failure             NaN                  NaN
#
#   medical_cause_of_death       pre_existing_medical_condition  \
# 0                    NaN  Developed condition after admission
# 1                    NaN       Pre-existing medical condition
# 2                    NaN       Pre-existing medical condition
# 3                    NaN  Developed condition after admission
# 4                    NaN       Pre-existing medical condition
#
#   medical_examinor_coroner_evalution medical_treatment  \
# 0                                 No               Yes
# 1                                 No               Yes
# 2                                 No               Yes
# 3                                 No               Yes
# 4                                 No               Yes
#
#                    ethnicity ethnicity_other other_behavior entry_behavior  \
# 0             Anglo or White             NaN            NaN           None
# 1             Anglo or White             NaN            NaN           None
# 2  Black or African American             NaN            NaN           None
# 3  Black or African American             NaN            NaN           None
# 4             Anglo or White             NaN            NaN           None
#
#   were_the_charges type_of_offense type_of_offense_other
# 0        Convicted           child                   NaN
# 1        Convicted        property                   NaN
# 2        Convicted         violent                   NaN
# 3        Convicted         violent                   NaN
# 4        Convicted           child                   NaN

# %% [markdown]
# ## Write

# %%
with dw.open_remote_file(DTW_PROJECT_KEY, CLEANED_FILENAME) as w:
    print("Writing to data.world:", CLEANED_FILENAME)
    df.to_csv(w, index=False)
# Out:
# Writing to data.world: reformatted_cdr_2017_master_file.csv
