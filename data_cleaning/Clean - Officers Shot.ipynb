# %% [markdown]
# # Clean the Texas OIS dataset for analysis -- officers shot data
#
# ### Latest run covers incidents from 2015-10-06 to 2018-03-25
#
# * Inputs:
#    * `OIS.xlsx` (currently local -- TODO add to data.world)
#    * `texas_law_enforcement_agencies_and_counties.csv` (dtw - used to add county information)
# * Output: `shot_officers.csv`
#
# ##### Author: Everett Wetchler (everett.wetchler@gmail.com)

# %% [markdown]
# ## 1. Setup and read data

# %%
DTW_PROJECT_KEY = 'tji/auxiliary-datasets'
AGENCY_COUNTY_DATAFRAME_NAME = 'texas_law_enforcement_agencies_and_counties'
# TODO(@wetchler): move OIS data to data.world
RAW_FILENAME = '../data/raw/OIS.xlsx'
CLEANED_FILENAME = '../data/clean/shot_officers.csv'

# %%
import datadotworld as dw
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %load_ext watermark
# %watermark -a "Everett Wetchler" -d -t -z -r -g -w -p datadotworld,numpy,pandas
# Out:
# Everett Wetchler 2018-05-07 20:39:00 CDT
#
# datadotworld 1.6.0
# numpy 1.14.3
# pandas 0.22.0
# Git hash: e4fec23b644d31575a9c5facc6948ef54e21a178
# Git repo: git@github.com:texas-justice-initiative/data-processing.git
# watermark 1.6.0

# %%
from lib.standardize_police_agency_names import standardize_agency_name
from lib.cleaning_tools import *

# %%
dtw_datasets = dw.load_dataset(DTW_PROJECT_KEY, force_update=True)
agencies = dtw_datasets.dataframes[AGENCY_COUNTY_DATAFRAME_NAME]
agencies.head()
# Out:
#      county                        agency
# 0  ANDERSON       ANDERSON CO CONST PCT 1
# 1  ANDERSON       ANDERSON CO CONST PCT 2
# 2  ANDERSON       ANDERSON CO CONST PCT 3
# 3  ANDERSON       ANDERSON CO CONST PCT 4
# 4  ANDERSON  ANDERSON CO DIST ATTY OFFICE

# %%
SHEET_NAME = 'OfficersShot'
shootings = pd.read_excel(RAW_FILENAME, sheetname=SHEET_NAME)
print("OIS officers-shot incidents from %s to %s" % (
    shootings['Date of Incident'].min().strftime('%Y-%m-%d'),
    shootings['Date of Incident'].max().strftime('%Y-%m-%d')))
shootings.head()
# Out:
# /Users/everettwetchler/.virtualenvs/jupyter-data-processing/lib/python3.6/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# OIS officers-shot incidents from 2015-10-06 to 2018-03-25
#    No.   Number of Reports Filed Date OAG Received Date of Report 1  \
# 0     1                        1               NaT       10/26/2015
# 1     2                        1               NaT        11/3/2015
# 2     3                        1        2017-02-21        2/21/2017
# 3     4                        1               NaT       12/29/2015
# 4     5                        1               NaT       12/29/2015
#
#                 Name of Agency 1 City of Agency 1 Zip code of Agency 1  \
# 0       Seguin Police Department           Seguin                78155
# 1  Bexar County Sheriff's Office      San Antonio                78207
# 2       Marlin Police Department           Marlin                76661
# 3       Odessa Police Department           Odessa                79761
# 4       Odessa Police Department           Odessa                79761
#
#   Date of Incident Name of Person 1 Filling out Form  \
# 0       2015-10-06                        MC Meyers
# 1       2015-10-30           Det. Frank Stubbs #4048
# 2       2015-11-01                     Damien Eaglin
# 3       2015-12-23                   Sgt. David Lara
# 4       2015-12-23                   Sgt. David Lara
#
#   Email Address of Person 1 Filling out Form Date of Report 2  \
# 0                   mcmeyers@seguintexas.gov              NaN
# 1                          sstubbs@bexar.org              NaN
# 2                   chiefeaglin@marlintx.net              NaN
# 3                        dlara@odessa-tx.gov              NaN
# 4                        dlara@odessa-tx.gov              NaN
#
#   Name of Agency 2 City of Agency 2  Zip code of Agency 2  \
# 0              NaN              NaN                   NaN
# 1              NaN              NaN                   NaN
# 2              NaN              NaN                   NaN
# 3              NaN              NaN                   NaN
# 4              NaN              NaN                   NaN
#
#   Name of Person 2 Filling out form  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#   Email Address of Person 2 Filling out Form Officer First Name  \
# 0                                        NaN                NaN
# 1                                        NaN             Joseph
# 2                                        NaN           Darrell
# 3                                        NaN               Pete
# 4                                        NaN              Cory
#
#   Officer Last Name Injured or Deceased's Gender  Injured or Deceased's Age  \
# 0               NaN                       Female                         54
# 1           Canales                         Male                         42
# 2             Allen                         Male                         42
# 3          Gonzales                         Male                         42
# 4            Wester                         Male                         38
#
#   Injured or Deceased's Race/Ethnicity Street Address of Incident  \
# 0                       Anglo or White            815 Lamar Drive
# 1                   Hispanic or Latino              8000 Midcrown
# 2            Black or African American            301 W. Avenue B
# 3                   Hispanic or Latino           1025 Custer Ave.
# 4                       Anglo or White           1025 Custer Ave.
#
#   City of Incident County of Incident  Zip Code of Incident  \
# 0           Seguin          Guadalupe                 78155
# 1      San Antonio              Bexar                 78218
# 2           Temple        Bell County                 76501
# 3           Odessa              Ector                 79761
# 4           Odessa              Ector                 79761
#
#    Latitude of Incident  Longitude of Incident   Incident Resulted In 1  \
# 0             29.576609             -97.947667  Injury of Peace Officer
# 1             29.507478             -98.380029  Injury of Peace Officer
# 2             31.095688             -97.344775   Death of Peace Officer
# 3             31.865143            -102.335850  Injury of Peace Officer
# 4             31.865143            -102.335850  Injury of Peace Officer
#
#   Incident Resulted In 2 Non-Peace Officer's Gender 1  \
# 0                    NaN                       Female
# 1                    NaN                         Male
# 2                    NaN                         Male
# 3                    NaN                         Male
# 4                    NaN                         Male
#
#   Non-Peace Officer's Age 1 Non-Peace Officer's Race/Ethnicity 1  \
# 0                        54                       Anglo or White
# 1                        36            Black or African American
# 2             Not Available                        Not Available
# 3                        27                   Hispanic or Latino
# 4                        27                   Hispanic or Latino
#
#   Non-Officer First Name 1 Non-Officer Last Name 1  \
# 0                      NaN                     NaN
# 1                  Sherman                Robinson
# 2                      NaN                     NaN
# 3               Roy Daniel                   Garza
# 4               Roy Daniel                   Garza
#
#   Non-Peace Officer's Gender 2  Non-Peace Officer's Age 2  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#   Non-Peace Officer's Race/Ethnicity 2 Non-Officer First Name 2  \
# 0                                  NaN                      NaN
# 1                                  NaN                      NaN
# 2                                  NaN                      NaN
# 3                                  NaN                      NaN
# 4                                  NaN                      NaN
#
#   Non-Officer Last Name 2 Non-Peace Officer's Gender 3  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#    Non-Peace Officer's Age 3 Non-Peace Officer's Race/Ethnicity 3  \
# 0                        NaN                                  NaN
# 1                        NaN                                  NaN
# 2                        NaN                                  NaN
# 3                        NaN                                  NaN
# 4                        NaN                                  NaN
#
#    Non-Officer First Name 3  Non-Officer Last Name 3                Media  \
# 0                       NaN                      NaN                  NaN
# 1                       NaN                      NaN                 MySA
# 2                       NaN                      NaN  Waco Tribune-Herald
# 3                       NaN                      NaN                CBS 7
# 4                       NaN                      NaN                CBS 7
#
#            Column1 Column2
# 0              NaN     NaN
# 1  News4SanAntonio     NaN
# 2              NaN     NaN
# 3      Big Country     NaN
# 4      Big Country     NaN

# %% [markdown]
# ## 2. Begin cleaning

# %% [markdown]
# ### Remove whitespace from column names

# %%
shootings.columns = [c.strip().lower() for c in shootings.columns]

# %% [markdown]
# ### Uppercase and strip all string cells

# %%
for col, dt in shootings.dtypes.items():
    if dt == 'object':
        print(col, end=', ')
        shootings[col] = shootings[col].apply(lambda s: s if type(s) != str else s.strip().upper())
# Out:
# date of report 1, name of agency 1, city of agency 1, zip code of agency 1, name of person 1 filling out form, email address of person 1 filling out form, date of report 2, name of agency 2, city of agency 2, name of person 2 filling out form, email address of person 2 filling out form, officer first name, officer last name, injured or deceased's gender, injured or deceased's race/ethnicity, street address of incident, city of incident, county of incident, incident resulted in 1, incident resulted in 2, non-peace officer's gender 1, non-peace officer's age 1, non-peace officer's race/ethnicity 1, non-officer first name 1, non-officer last name 1, non-peace officer's gender 2, non-peace officer's race/ethnicity 2, non-officer first name 2, non-officer last name 2, non-peace officer's gender 3, non-peace officer's race/ethnicity 3, media, column1, column2,

# %% [markdown]
# ### Drop unnecessary columns

# %%
shootings.drop(['no.', 'number of reports filed'], axis=1, inplace=True)

# %% [markdown]
# ### Make column names more machine-friendly

# %%
col_renames = {
    "date oag received": "date_ag_received",
    "date of incident": "date_incident",
    "officer first name": "officer_name_first",
    "officer last name": "officer_name_last",
    "injured or deceased's gender": "officer_gender",
    "injured or deceased's age": "officer_age",
    "injured or deceased's race/ethnicity": "officer_race",
    "street address of incident": "incident_address",
    "city of incident": "incident_city",
    "county of incident": "incident_county",
    "zip code of incident": "incident_zip",
    "latitude of incident": "incident_latitude",
    "longitude of incident": "incident_longitude",
    "incident resulted in 1": "incident_result_1",
    "incident resulted in 2": "incident_result_2",
    "media": "media_link_1",
    "column1": "media_link_2",
    "column2": "media_link_3",
}

agency_col_renames = {
    "date of report %d": "agency_%d_report_date",
    "name of agency %d": "agency_%d_name",
    "city of agency %d": "agency_%d_city",
    "zip code of agency %d": "agency_%d_zip",
    "name of person %d filling out form": "agency_%d_name_person_filling_out",
    "email address of person %d filling out form": "agency_%d_email_person_filling_out",
}

for i in range(1, 3):
    for k, v in agency_col_renames.items():
        k = k % i
        v = v % i
        col_renames[k] = v


civilian_col_renames = {
    "non-peace officer's gender %d": "civilian_%d_gender",
    "non-peace officer's age %d": "civilian_%d_age",
    "non-peace officer's race/ethnicity %d": "civilian_%d_race",
    "non-officer first name %d": "civilian_%d_name_first",
    "non-officer last name %d": "civilian_%d_name_last",
}

for i in range(1, 4):
    for k, v in civilian_col_renames.items():
        k = k % i
        v = v % i
        col_renames[k] = v

# %%
shootings.columns = [col_renames[c] for c in shootings.columns]

# %% [markdown]
# ### Translate columns about injury vs death to boolean

# %%
def death_injury_officer(s):
    if pd.isnull(s):
        return s
    elif 'death' in s.lower():
        return True
    elif 'injury' in s.lower():
        return False
    raise CleaningError('Invalid incident result: ' + s)

def death_injury_civilian(s):
    try:
        return death_injury_officer(s)
    except CleaningError as e:
        if 'suicide' in s.lower():
            return True
        raise

shootings['officer_died'] = shootings['incident_result_1'].apply(death_injury_officer)
shootings['civilian_died'] = shootings['incident_result_2'].apply(death_injury_civilian)
shootings['civilian_suicide'] = shootings['incident_result_2'].str.contains('suicide')
shootings.drop(['incident_result_1', 'incident_result_2'], axis=1, inplace=True)

# %% [markdown]
# ### Replace 'Not Available' string values with true missing values

# %%
for c in shootings.columns:
    if shootings[c].dtype == 'object':
        shootings[c][shootings[c] == 'NOT AVAILABLE'] = None
# Out:
# /Users/everettwetchler/.virtualenvs/jupyter-data-processing/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Convert "12345-6789" style zips into simply "12345"

# %%
for c in shootings.columns:
    if c.endswith('_zip'):
        shootings[c] = shootings[c].apply(lambda z: z if pd.isnull(z) else str(z).split('-')[0])

# %% [markdown]
# ### Ensure ages are all valid integers

# %% [markdown]
# ### Validate gender columns

# %%
validate_gender_cols(shootings)

# %% [markdown]
# ### Make age columns numerical (float)

# %%
numericalize_age_cols(shootings)

# %% [markdown]
# ### Simplify race names

# %%
standardize_race_cols(shootings)

# %% [markdown]
# ### Convert date columns to ensure validity

# %%
for c in shootings.columns:
    if c.startswith('date_') or c.endswith('_date'):
        shootings[c] = pd.to_datetime(shootings[c])

# %%
shootings.head()
# Out:
#   date_ag_received agency_1_report_date                  agency_1_name  \
# 0              NaT           2015-10-26       SEGUIN POLICE DEPARTMENT
# 1              NaT           2015-11-03  BEXAR COUNTY SHERIFF'S OFFICE
# 2       2017-02-21           2017-02-21       MARLIN POLICE DEPARTMENT
# 3              NaT           2015-12-29       ODESSA POLICE DEPARTMENT
# 4              NaT           2015-12-29       ODESSA POLICE DEPARTMENT
#
#   agency_1_city agency_1_zip date_incident agency_1_name_person_filling_out  \
# 0        SEGUIN        78155    2015-10-06                        MC MEYERS
# 1   SAN ANTONIO        78207    2015-10-30          DET. FRANK STUBBS #4048
# 2        MARLIN        76661    2015-11-01                    DAMIEN EAGLIN
# 3        ODESSA        79761    2015-12-23                  SGT. DAVID LARA
# 4        ODESSA        79761    2015-12-23                  SGT. DAVID LARA
#
#   agency_1_email_person_filling_out agency_2_report_date agency_2_name  \
# 0          MCMEYERS@SEGUINTEXAS.GOV                  NaT           NaN
# 1                 SSTUBBS@BEXAR.ORG                  NaT           NaN
# 2          CHIEFEAGLIN@MARLINTX.NET                  NaT           NaN
# 3               DLARA@ODESSA-TX.GOV                  NaT           NaN
# 4               DLARA@ODESSA-TX.GOV                  NaT           NaN
#
#   agency_2_city agency_2_zip agency_2_name_person_filling_out  \
# 0           NaN          NaN                              NaN
# 1           NaN          NaN                              NaN
# 2           NaN          NaN                              NaN
# 3           NaN          NaN                              NaN
# 4           NaN          NaN                              NaN
#
#   agency_2_email_person_filling_out officer_name_first officer_name_last  \
# 0                               NaN                NaN               NaN
# 1                               NaN             JOSEPH           CANALES
# 2                               NaN            DARRELL             ALLEN
# 3                               NaN               PETE          GONZALES
# 4                               NaN               CORY            WESTER
#
#   officer_gender  officer_age officer_race  incident_address incident_city  \
# 0         FEMALE         54.0        WHITE   815 LAMAR DRIVE        SEGUIN
# 1           MALE         42.0     HISPANIC     8000 MIDCROWN   SAN ANTONIO
# 2           MALE         42.0        BLACK   301 W. AVENUE B        TEMPLE
# 3           MALE         42.0     HISPANIC  1025 CUSTER AVE.        ODESSA
# 4           MALE         38.0        WHITE  1025 CUSTER AVE.        ODESSA
#
#   incident_county incident_zip  incident_latitude  incident_longitude  \
# 0       GUADALUPE        78155          29.576609          -97.947667
# 1           BEXAR        78218          29.507478          -98.380029
# 2     BELL COUNTY        76501          31.095688          -97.344775
# 3           ECTOR        79761          31.865143         -102.335850
# 4           ECTOR        79761          31.865143         -102.335850
#
#   civilian_1_gender  civilian_1_age civilian_1_race civilian_1_name_first  \
# 0            FEMALE            54.0           WHITE                   NaN
# 1              MALE            36.0           BLACK               SHERMAN
# 2              MALE             NaN            None                   NaN
# 3              MALE            27.0        HISPANIC            ROY DANIEL
# 4              MALE            27.0        HISPANIC            ROY DANIEL
#
#   civilian_1_name_last civilian_2_gender  civilian_2_age civilian_2_race  \
# 0                  NaN               NaN             NaN             NaN
# 1             ROBINSON               NaN             NaN             NaN
# 2                  NaN               NaN             NaN             NaN
# 3                GARZA               NaN             NaN             NaN
# 4                GARZA               NaN             NaN             NaN
#
#   civilian_2_name_first civilian_2_name_last civilian_3_gender  \
# 0                   NaN                  NaN               NaN
# 1                   NaN                  NaN               NaN
# 2                   NaN                  NaN               NaN
# 3                   NaN                  NaN               NaN
# 4                   NaN                  NaN               NaN
#
#    civilian_3_age civilian_3_race  civilian_3_name_first  \
# 0             NaN             NaN                    NaN
# 1             NaN             NaN                    NaN
# 2             NaN             NaN                    NaN
# 3             NaN             NaN                    NaN
# 4             NaN             NaN                    NaN
#
#    civilian_3_name_last         media_link_1     media_link_2 media_link_3  \
# 0                   NaN                  NaN              NaN          NaN
# 1                   NaN                 MYSA  NEWS4SANANTONIO          NaN
# 2                   NaN  WACO TRIBUNE-HERALD              NaN          NaN
# 3                   NaN                CBS 7      BIG COUNTRY          NaN
# 4                   NaN                CBS 7      BIG COUNTRY          NaN
#
#    officer_died civilian_died civilian_suicide
# 0         False           NaN              NaN
# 1         False           NaN              NaN
# 2          True           NaN              NaN
# 3         False           NaN              NaN
# 4         False           NaN              NaN

# %% [markdown]
# ### Standardize agency names

# %%
for c in shootings.columns:
    if c.startswith('agency_') and c.endswith('_name'):
        shootings[c + '_standardized'] = shootings[c].apply(standardize_agency_name)

# %% [markdown]
# ### Add agency county information

# %%
agency_to_county = dict(zip(agencies.agency, agencies.county))
for i in (1, 2):
    k = 'agency_%d_name_standardized' % i
    shootings = insert_col_after(
        shootings,
        shootings[k].apply(lambda d: agency_to_county.get(d, np.nan)),
        'agency_%d_county' % i,
        'agency_%d_city' % i)

shootings[shootings.agency_1_county.isnull()]
# Out:
#    date_ag_received agency_1_report_date                        agency_1_name  \
# 28       2017-02-01           2017-01-31  EL CENTRO COLLEGE POLICE DEPARTMENT
# 29       2017-02-01           2017-01-31  EL CENTRO COLLEGE POLICE DEPARTMENT
#
#    agency_1_city agency_1_county agency_1_zip date_incident  \
# 28        DALLAS             NaN        75202    2016-07-07
# 29        DALLAS             NaN        75202    2016-07-07
#
#    agency_1_name_person_filling_out agency_1_email_person_filling_out  \
# 28                       REX GASTON                 RGASTON@DCCCD.EDU
# 29                       REX GASTON                 RGASTON@DCCCD.EDU
#
#    agency_2_report_date agency_2_name agency_2_city agency_2_county  \
# 28                  NaT           NaN           NaN             NaN
# 29                  NaT           NaN           NaN             NaN
#
#    agency_2_zip agency_2_name_person_filling_out  \
# 28          NaN                              NaN
# 29          NaN                              NaN
#
#    agency_2_email_person_filling_out officer_name_first officer_name_last  \
# 28                               NaN                NaN               NaN
# 29                               NaN                NaN               NaN
#
#    officer_gender  officer_age officer_race incident_address incident_city  \
# 28           MALE         36.0        WHITE     157 N. LAMAR        DALLAS
# 29           MALE         42.0        WHITE     157 N. LAMAR        DALLAS
#
#    incident_county incident_zip  incident_latitude  incident_longitude  \
# 28          DALLAS        75202          32.780004          -96.804429
# 29          DALLAS        75202          32.780004          -96.804429
#
#    civilian_1_gender  civilian_1_age civilian_1_race civilian_1_name_first  \
# 28              MALE            25.0           BLACK          MICAH XAVIER
# 29              MALE            25.0           BLACK          MICAH XAVIER
#
#    civilian_1_name_last civilian_2_gender  civilian_2_age civilian_2_race  \
# 28              JOHNSON               NaN             NaN             NaN
# 29              JOHNSON               NaN             NaN             NaN
#
#    civilian_2_name_first civilian_2_name_last civilian_3_gender  \
# 28                   NaN                  NaN               NaN
# 29                   NaN                  NaN               NaN
#
#     civilian_3_age civilian_3_race  civilian_3_name_first  \
# 28             NaN             NaN                    NaN
# 29             NaN             NaN                    NaN
#
#     civilian_3_name_last media_link_1 media_link_2 media_link_3  officer_died  \
# 28                   NaN          NaN          NaN          NaN         False
# 29                   NaN          NaN          NaN          NaN         False
#
#    civilian_died civilian_suicide     agency_1_name_standardized  \
# 28          True            False  EL CENTRO COLLEGE POLICE DEPT
# 29          True            False  EL CENTRO COLLEGE POLICE DEPT
#
#    agency_2_name_standardized
# 28                       None
# 29                       None

# %% [markdown]
# ### Fix erroneous counties

# %%
counties = set(agencies.county)
shootings[~shootings.incident_county.isin(counties)]
# Out:
#    date_ag_received agency_1_report_date                 agency_1_name  \
# 2        2017-02-21           2017-02-21      MARLIN POLICE DEPARTMENT
# 50       2017-05-17           2017-05-17     KILLEEN POLICE DEPARTMENT
# 71       2018-02-23           2018-02-22  RICHARDSON POLICE DEPARTMENT
#
#    agency_1_city agency_1_county agency_1_zip date_incident  \
# 2         MARLIN           FALLS        76661    2015-11-01
# 50       KILLEEN            BELL        76542    2017-04-24
# 71    RICHARDSON          DALLAS        75081    2018-02-07
#
#    agency_1_name_person_filling_out agency_1_email_person_filling_out  \
# 2                     DAMIEN EAGLIN          CHIEFEAGLIN@MARLINTX.NET
# 50               CDR. ALEX GEARHART        AGEARHART@KILLEENTEXAS.GOV
# 71            SGT. KEVIN W. PERLICH             KEVIN.PERLICH@COR.GOV
#
#    agency_2_report_date agency_2_name agency_2_city agency_2_county  \
# 2                   NaT           NaN           NaN             NaN
# 50                  NaT           NaN           NaN             NaN
# 71                  NaT           NaN           NaN             NaN
#
#    agency_2_zip agency_2_name_person_filling_out  \
# 2           NaN                              NaN
# 50          NaN                              NaN
# 71          NaN                              NaN
#
#    agency_2_email_person_filling_out officer_name_first officer_name_last  \
# 2                                NaN            DARRELL             ALLEN
# 50                               NaN                NaN               NaN
# 71                               NaN       DAVID STEFAN          SHERRARD
#
#    officer_gender  officer_age officer_race  \
# 2            MALE         42.0        BLACK
# 50           MALE         40.0        WHITE
# 71           MALE         37.0        WHITE
#
#                              incident_address incident_city incident_county  \
# 2                             301 W. AVENUE B        TEMPLE     BELL COUNTY
# 50           3207 E. CENTRAL TEXAS EXPRESSWAY       KILLEEN     BELL COUNTY
# 71  3500 NORTH STAR ROAD, BLDG. 12, APT. 1235    RICHARDSON           COLIN
#
#    incident_zip  incident_latitude  incident_longitude civilian_1_gender  \
# 2         76501          31.095688          -97.344775              MALE
# 50        76543          31.087794          -97.707175              MALE
# 71        75082          32.999521          -96.640781              MALE
#
#     civilian_1_age civilian_1_race   civilian_1_name_first  \
# 2              NaN            None                     NaN
# 50            15.0           BLACK  DAEZION CHRISTIAN PAUL
# 71            26.0           WHITE                 BRANDON
#
#    civilian_1_name_last civilian_2_gender  civilian_2_age civilian_2_race  \
# 2                   NaN               NaN             NaN             NaN
# 50               TURNER               NaN             NaN             NaN
# 71               MCCALL               NaN             NaN             NaN
#
#    civilian_2_name_first civilian_2_name_last civilian_3_gender  \
# 2                    NaN                  NaN               NaN
# 50                   NaN                  NaN               NaN
# 71                   NaN                  NaN               NaN
#
#     civilian_3_age civilian_3_race  civilian_3_name_first  \
# 2              NaN             NaN                    NaN
# 50             NaN             NaN                    NaN
# 71             NaN             NaN                    NaN
#
#     civilian_3_name_last         media_link_1 media_link_2 media_link_3  \
# 2                    NaN  WACO TRIBUNE-HERALD          NaN          NaN
# 50                   NaN             KDH NEWS          NaN          NaN
# 71                   NaN  DALLAS MORNING NEWS      NBC DFW          NaN
#
#     officer_died civilian_died civilian_suicide agency_1_name_standardized  \
# 2           True           NaN              NaN         MARLIN POLICE DEPT
# 50         False          True            False        KILLEEN POLICE DEPT
# 71          True           NaN              NaN     RICHARDSON POLICE DEPT
#
#    agency_2_name_standardized
# 2                        None
# 50                       None
# 71                       None

# %%
fixes = {
    'COLIN': 'COLLIN',
    'BELL COUNTY': 'BELL'
}
for before, after in fixes.items():
    shootings.loc[shootings.incident_county == before, 'incident_county'] = after

shootings[~shootings.incident_county.isin(counties)]
# Out:
# Empty DataFrame
# Columns: [date_ag_received, agency_1_report_date, agency_1_name, agency_1_city, agency_1_county, agency_1_zip, date_incident, agency_1_name_person_filling_out, agency_1_email_person_filling_out, agency_2_report_date, agency_2_name, agency_2_city, agency_2_county, agency_2_zip, agency_2_name_person_filling_out, agency_2_email_person_filling_out, officer_name_first, officer_name_last, officer_gender, officer_age, officer_race, incident_address, incident_city, incident_county, incident_zip, incident_latitude, incident_longitude, civilian_1_gender, civilian_1_age, civilian_1_race, civilian_1_name_first, civilian_1_name_last, civilian_2_gender, civilian_2_age, civilian_2_race, civilian_2_name_first, civilian_2_name_last, civilian_3_gender, civilian_3_age, civilian_3_race, civilian_3_name_first, civilian_3_name_last, media_link_1, media_link_2, media_link_3, officer_died, civilian_died, civilian_suicide, agency_1_name_standardized, agency_2_name_standardized]
# Index: []

# %% [markdown]
# ### Re-order columns more sensibly

# %%
section_order = ['date', 'incident', 'officer', 'civilian', 'agency', 'media']
new_col_order = []
for s in section_order:
    this_section_cols = []
    for c in shootings.columns:
        if c.startswith(s + '_'):
            this_section_cols.append(c)
    new_col_order.extend(sorted(this_section_cols))

shape_before = shootings.shape
shootings = shootings[new_col_order]
assert(shootings.shape == shape_before)

# %%
shootings.sort_values(['date_incident', 'incident_county'], inplace=True)
shootings.head()
# Out:
#   date_ag_received date_incident  incident_address incident_city  \
# 0              NaT    2015-10-06   815 LAMAR DRIVE        SEGUIN
# 1              NaT    2015-10-30     8000 MIDCROWN   SAN ANTONIO
# 2       2017-02-21    2015-11-01   301 W. AVENUE B        TEMPLE
# 3              NaT    2015-12-23  1025 CUSTER AVE.        ODESSA
# 4              NaT    2015-12-23  1025 CUSTER AVE.        ODESSA
#
#   incident_county  incident_latitude  incident_longitude incident_zip  \
# 0       GUADALUPE          29.576609          -97.947667        78155
# 1           BEXAR          29.507478          -98.380029        78218
# 2            BELL          31.095688          -97.344775        76501
# 3           ECTOR          31.865143         -102.335850        79761
# 4           ECTOR          31.865143         -102.335850        79761
#
#    officer_age  officer_died officer_gender officer_name_first  \
# 0         54.0         False         FEMALE                NaN
# 1         42.0         False           MALE             JOSEPH
# 2         42.0          True           MALE            DARRELL
# 3         42.0         False           MALE               PETE
# 4         38.0         False           MALE               CORY
#
#   officer_name_last officer_race  civilian_1_age civilian_1_gender  \
# 0               NaN        WHITE            54.0            FEMALE
# 1           CANALES     HISPANIC            36.0              MALE
# 2             ALLEN        BLACK             NaN              MALE
# 3          GONZALES     HISPANIC            27.0              MALE
# 4            WESTER        WHITE            27.0              MALE
#
#   civilian_1_name_first civilian_1_name_last civilian_1_race  civilian_2_age  \
# 0                   NaN                  NaN           WHITE             NaN
# 1               SHERMAN             ROBINSON           BLACK             NaN
# 2                   NaN                  NaN            None             NaN
# 3            ROY DANIEL                GARZA        HISPANIC             NaN
# 4            ROY DANIEL                GARZA        HISPANIC             NaN
#
#   civilian_2_gender civilian_2_name_first civilian_2_name_last  \
# 0               NaN                   NaN                  NaN
# 1               NaN                   NaN                  NaN
# 2               NaN                   NaN                  NaN
# 3               NaN                   NaN                  NaN
# 4               NaN                   NaN                  NaN
#
#   civilian_2_race  civilian_3_age civilian_3_gender  civilian_3_name_first  \
# 0             NaN             NaN               NaN                    NaN
# 1             NaN             NaN               NaN                    NaN
# 2             NaN             NaN               NaN                    NaN
# 3             NaN             NaN               NaN                    NaN
# 4             NaN             NaN               NaN                    NaN
#
#    civilian_3_name_last civilian_3_race civilian_died civilian_suicide  \
# 0                   NaN             NaN           NaN              NaN
# 1                   NaN             NaN           NaN              NaN
# 2                   NaN             NaN           NaN              NaN
# 3                   NaN             NaN           NaN              NaN
# 4                   NaN             NaN           NaN              NaN
#
#   agency_1_city agency_1_county agency_1_email_person_filling_out  \
# 0        SEGUIN       GUADALUPE          MCMEYERS@SEGUINTEXAS.GOV
# 1   SAN ANTONIO           BEXAR                 SSTUBBS@BEXAR.ORG
# 2        MARLIN           FALLS          CHIEFEAGLIN@MARLINTX.NET
# 3        ODESSA           ECTOR               DLARA@ODESSA-TX.GOV
# 4        ODESSA           ECTOR               DLARA@ODESSA-TX.GOV
#
#                    agency_1_name agency_1_name_person_filling_out  \
# 0       SEGUIN POLICE DEPARTMENT                        MC MEYERS
# 1  BEXAR COUNTY SHERIFF'S OFFICE          DET. FRANK STUBBS #4048
# 2       MARLIN POLICE DEPARTMENT                    DAMIEN EAGLIN
# 3       ODESSA POLICE DEPARTMENT                  SGT. DAVID LARA
# 4       ODESSA POLICE DEPARTMENT                  SGT. DAVID LARA
#
#   agency_1_name_standardized agency_1_report_date agency_1_zip agency_2_city  \
# 0         SEGUIN POLICE DEPT           2015-10-26        78155           NaN
# 1   BEXAR CO SHERIFFS OFFICE           2015-11-03        78207           NaN
# 2         MARLIN POLICE DEPT           2017-02-21        76661           NaN
# 3         ODESSA POLICE DEPT           2015-12-29        79761           NaN
# 4         ODESSA POLICE DEPT           2015-12-29        79761           NaN
#
#   agency_2_county agency_2_email_person_filling_out agency_2_name  \
# 0             NaN                               NaN           NaN
# 1             NaN                               NaN           NaN
# 2             NaN                               NaN           NaN
# 3             NaN                               NaN           NaN
# 4             NaN                               NaN           NaN
#
#   agency_2_name_person_filling_out agency_2_name_standardized  \
# 0                              NaN                       None
# 1                              NaN                       None
# 2                              NaN                       None
# 3                              NaN                       None
# 4                              NaN                       None
#
#   agency_2_report_date agency_2_zip         media_link_1     media_link_2  \
# 0                  NaT          NaN                  NaN              NaN
# 1                  NaT          NaN                 MYSA  NEWS4SANANTONIO
# 2                  NaT          NaN  WACO TRIBUNE-HERALD              NaN
# 3                  NaT          NaN                CBS 7      BIG COUNTRY
# 4                  NaT          NaN                CBS 7      BIG COUNTRY
#
#   media_link_3
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ## 3. Write

# %%
shootings.to_csv(CLEANED_FILENAME, index=False)
